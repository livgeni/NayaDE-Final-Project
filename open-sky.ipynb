# %%
# Install opensky_api module - run once
# Will only work in a jupyter notebook

import platform
import importlib
import os

class StopExecution(Exception):
    def _render_traceback_(self):
        pass

openskye_api_installed = importlib.util.find_spec("opensky_api")
if openskye_api_installed != None:
    print('opensky_api module already installed')
else:
    system = platform.system()

    if system == 'Windows':
        print('System is Windows...')
        path_7zip = os.path.abspath(r'c:\Program Files\7-Zip\7z.exe')
        if not os.path.isfile(path_7zip):
            print('no 7zip installed - please install')
            raise StopExecution
        print('Donwloading the opensky_api package')
        # !certutil -urlcache -split -f "https://github.com/openskynetwork/opensky-api/archive/master.zip" ./master.zip
        !"$path_7zip" x ./master.zip
        # !pip install -e "./opensky-api-master/python"
    elif system == 'Linux':
        print('System is Linux...')
        print('Donwloading the opensky_api package')
        # !wget "https://github.com/openskynetwork/opensky-api/archive/master.zip"
        # !unzip -o ./master.zip
        # !pip install -e "./opensky-api-master/python"
print('Restarting kernel')
from IPython.core.display import HTML
HTML("<script>Jupyter.notebook.kernel.restart()</script>")
print('Done')
# Out:
# System is Windows...
# Donwloading the opensky_api package
# ****  Online  ****
#   000000  ...
#   01dfa5
# CertUtil: -URLCache command FAILED: 0x80072f8f (WIN32: 12175)
# CertUtil: A security error occurred

# %%
# Out:
# <script>Jupyter.notebook.kernel.restart()</script>

# %%
from opensky_api import OpenSkyApi

api = OpenSkyApi('livgeni', '1abc23')
s = api.get_states()
len(s.states)
# Out:
# 6477

# %%
import json
from pprint import pprint

red_fields = ['origin_country', 'sensors']
yellow_fields = ['time_position', 'heading', 'vertical_rate', 'spi']

svdl = list()

for sv in s.states:
    svd = dict()
    svd = {'time':s.time}
    for key in sv.keys:
        if key not in red_fields:
            val = sv.__dict__[key]
            svd[key] = val if type(val) != str else val.strip()
        
    svdl += [svd]

svjl = json.dumps(svdl)

# svdl[:3]
# svj = json.dumps(svd)

# %%
j = json.loads(svjl)
[state for state in j if state['on_ground']]
# Out:
# [{'time': 1575984180,
#   'icao24': '880457',
#   'callsign': 'AIQ639',
#   'time_position': 1575983919,
#   'last_contact': 1575983925,
#   'longitude': 100.6282,
#   'latitude': 13.9546,
#   'baro_altitude': None,
#   'on_ground': True,
#   'velocity': 79.9,
#   'heading': 208.88,
#   'vertical_rate': -4.23,
#   'geo_altitude': None,
#   'squawk': '5503',
#   'spi': False,
#   'position_source': 0},
#  {'time': 1575984180,
#   'icao24': '4b1801',
#   'callsign': 'SWR119Z',
#   'time_position': 1575984084,
#   'last_contact': 1575984087,
#   'longitude': 9.1936,
#   'latitude': 48.6889,
#   'baro_altitude': None,
#   'on_ground': True,
#   'velocity': 0.64,
#   'heading': 343,
#   'vertical_rate': None,
#   'geo_altitude': None,
#   'squawk': '3033',
#   'spi': False,
#   'position_source': 0},
#  {'time': 1575984180,
#   'icao24': '8a02ea',
#   'callsign': 'LNI650',
#   'time_position': 1575983958,
#   'last_contact': 1575984004,
#   'longitude': 108.1809,
#   'latitude': -6.6105,
# ...

# %%
import numpy as np
import pandas as pd

pd_callsigns = pd.Series(callsigns)
# print(pd_callsigns.value_counts())
print(pd_callsigns.index)
# Out:
# RangeIndex(start=0, stop=6472, step=1)

# %%
fake_states = callsigns
fake_states.append(callsigns[0])
print(len(fake_states))
state_set = set(callsigns)
len(state_set)
# Out:
# 5360
# 5046

# %%
from datetime import datetime

api = OpenSkyApi('livgeni', '1abc23')

for state_vector in open_sky_generator(api):
    print(f'{datetime.fromtimestamp(state_vector.time)} : {len(state_vector.states)} : {state_vector.states[0].callsign}')
# Out:
# 2019-12-02 21:18:05 : 7527 : AAL1212
# 2019-12-02 21:18:19 : 7536 : AAL1212
# 2019-12-02 21:18:30 : 7559 : AAL1212
# 2019-12-02 21:18:45 : 7560 : AAL1212
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-78-1ea667207a98> in <module>
#       3 api = OpenSkyApi('livgeni', '1abc23')
#       4
# ----> 5 for state_vector in open_sky_generator(api):
#       6     print(f'{datetime.fromtimestamp(state_vector.time)} : {len(state_vector.states)} : {state_vector.states[0].callsign}')
#
# <ipython-input-72-a4b80970e354> in open_sky_generator(api)
#       4     while True:
#       5         yield api.get_states()
# ----> 6         sleep(10)
#
# KeyboardInterrupt:

# %%
s.states[0]
# Out:
# StateVector(dict_values(['ac96b8', 'AAL1212 ', 'United States', 1575310224, 1575310229, -85.8066, 36.9856, 10363.2, False, 216.76, 248.12, 0.33, None, 10294.62, '1340', False, 0]))

# %%
from datetime import datetime
print(datetime.fromtimestamp(s.time))
# Out:
# 2019-12-02 20:35:15

# %%
import requests
import json



url = "https://livgeni:1abc23@opensky-network.org/api/flights/all?begin=1517228200&end=1517231800"

res = requests.get(url)

if res.status_code == 404:
    print(res.__dir__())
    print(res.reason)
else:
    print(res.status_code)

#print(res.text)
    
jsn = json.loads(res.text)

print(len(jsn))
# Out:
# 200
# 451

# %%
from datetime import datetime

print(datetime.fromtimestamp(1517227200))

print(datetime.fromtimestamp(1517230800))
# Out:
# 2018-01-29 14:00:00
# 2018-01-29 15:00:00

# %%
import requests

url = r"https://www.google.com/maps/place/%D7%A7%D7%A0%D7%98%D7%A7%D7%99,+%D7%90%D7%A8%D7%A6%D7%95%D7%AA+%D7%94%D7%91%D7%A8%D7%99%D7%AA%E2%80%AD/@37.8191511,-84.6471581,8z/data=!3m1!4b1!4m5!3m4!1s0x8842734c8b1953c9:0x771f6f4ec5ccdffc!8m2!3d37.8393332!4d-84.2700179"

res = requests.get(url)

# %%
res.text
# Out:
# '<!DOCTYPE html><html dir="rtl" itemscope="" itemtype="http://schema.org/Place" lang="iw"> <head> <link href="/maps/preview/opensearch.xml?hl=iw" title="מפות Google" rel="search" type="application/opensearchdescription+xml"> <title> מפות \u202aGoogle\u202c\u200f </title> <meta content="אתר עסקים מקומיים, הצג מפות וקבל הוראות נסיעה ב\'מפות Google\'." name="Description">  <meta content="initial-scale=1.0, maximum-scale=1.0, minimum-scale=1.0, user-scalable=no" name="viewport"> <meta content="chrome=1" http-equiv="X-UA-Compatible"> <meta content="notranslate" name="google"> <meta content="origin" name="referrer">   <meta content="קנטקי" itemprop="name"> <meta content="קנטקי" property="og:title"> <meta content="//lh5.googleusercontent.com/proxy/ARHj4sGWWeqIvON9mIrphSvc1hO7jaWZnARfrO7zdZ3n9fyMAV0KC8AzSf5qynB1ixUKGW0mxgxdkGQXqe9Vq5RAlcfXXxrrhyXG9r-t2f68vnPXLz6rrfxMVuD-gdngj5qdlIvtPTCPD8c0WbZJVWvglJjLjg=w129-h86-k-no" itemprop="image"> <meta content="//lh5.googleusercontent.com/proxy/ARHj4s
# ...
